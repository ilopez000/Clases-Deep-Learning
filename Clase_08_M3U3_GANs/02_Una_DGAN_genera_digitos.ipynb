# %% [markdown]
# # Clase 8 · Notebook 02
# # Una DGAN que genera imágenes de dígitos
#
# **Introducción al Deep Learning — Módulo 3, Unidad 3: Redes Generativas Adversarias (GANs)**
#
# Aplicamos la idea adversaria a **imágenes**. Construiremos una **DGAN** (GAN profunda) que aprende a generar
# imágenes de dígitos (8×8) a partir de ruido, con la arquitectura vista en teoría:
#
# - **Generador**: `Dense → Reshape → Conv2DTranspose → LeakyReLU → BatchNormalization`.
# - **Discriminador**: una CNN de clasificación binaria (real / falso).
#
# Usamos el dataset `digits` (8×8) para que entrene rápido y sin descargas.
#
# > 💡 En Colab, TensorFlow ya viene instalado. Ejecuta las celdas en orden con **Shift + Enter**.
# > Entrenar una GAN es lento; con más épocas las imágenes mejoran.

# %% [markdown]
# ## 1. Preparar las imágenes reales

# %%
try:
    import tensorflow as tf
except ImportError:
    import sys, subprocess
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "tensorflow"])
    import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
tf.random.set_seed(42); np.random.seed(42)

digits = load_digits()
X = (digits.images.reshape(-1, 8, 8, 1).astype("float32") / 16.0)   # normalizado 0-1
print("Imágenes reales:", X.shape)

fig, axes = plt.subplots(1, 8, figsize=(11, 1.6))
for ax, im in zip(axes, X[:8]):
    ax.imshow(im.reshape(8, 8), cmap="gray"); ax.axis("off")
fig.suptitle("Dígitos reales", y=1.1); plt.show()

# %% [markdown]
# ## 2. El generador (de ruido a imagen)
#
# Parte de un vector de ruido, lo proyecta con `Dense`, lo convierte en una pequeña imagen con `Reshape`
# y la amplía con `Conv2DTranspose` hasta 8×8.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Dense, Reshape, Conv2DTranspose, Conv2D,
                                     LeakyReLU, BatchNormalization, Flatten, Input)

DIM_RUIDO = 16

generador = Sequential([
    Input(shape=(DIM_RUIDO,)),
    Dense(2 * 2 * 32), Reshape((2, 2, 32)),
    Conv2DTranspose(32, 3, strides=2, padding="same"), BatchNormalization(), LeakyReLU(0.2),  # 4x4
    Conv2DTranspose(16, 3, strides=2, padding="same"), BatchNormalization(), LeakyReLU(0.2),  # 8x8
    Conv2D(1, 3, padding="same", activation="sigmoid"),                                       # imagen 8x8
], name="generador")
print("Salida del generador:", generador.output_shape)

# %% [markdown]
# ## 3. El discriminador (real o falso)

# %%
discriminador = Sequential([
    Input(shape=(8, 8, 1)),
    Conv2D(16, 3, strides=2, padding="same"), LeakyReLU(0.2),
    Conv2D(32, 3, strides=2, padding="same"), LeakyReLU(0.2),
    Flatten(),
    Dense(1, activation="sigmoid"),
], name="discriminador")

bce = tf.keras.losses.BinaryCrossentropy()
opt_g = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
opt_d = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
print("Discriminador listo.")

# %% [markdown]
# ## 4. Bucle de entrenamiento adversario
#
# En cada paso entrenamos el discriminador (real=1, falso=0) y luego el generador (que quiere que sus
# imágenes se clasifiquen como reales).

# %%
@tf.function
def paso(reales):
    n = tf.shape(reales)[0]
    z = tf.random.normal((n, DIM_RUIDO))
    with tf.GradientTape() as td:
        falsas = generador(z, training=True)
        loss_d = bce(tf.ones_like(discriminador(reales)), discriminador(reales, training=True)) \
               + bce(tf.zeros_like(discriminador(falsas)), discriminador(falsas, training=True))
    g = td.gradient(loss_d, discriminador.trainable_variables)
    opt_d.apply_gradients(zip(g, discriminador.trainable_variables))

    z = tf.random.normal((n, DIM_RUIDO))
    with tf.GradientTape() as tg:
        falsas = generador(z, training=True)
        loss_g = bce(tf.ones_like(discriminador(falsas)), discriminador(falsas, training=True))
    g = tg.gradient(loss_g, generador.trainable_variables)
    opt_g.apply_gradients(zip(g, generador.trainable_variables))
    return loss_d, loss_g

EPOCAS, BATCH = 40, 64
for e in range(EPOCAS):
    idx = np.random.permutation(len(X))
    for i in range(0, len(X), BATCH):
        ld, lg = paso(X[idx[i:i+BATCH]])
    if e % 10 == 0:
        print(f"época {e:2d} | loss_D {ld.numpy():.3f} | loss_G {lg.numpy():.3f}")
print("Entrenamiento terminado.")

# %% [markdown]
# ## 5. Imágenes generadas por la red

# %%
z = tf.random.normal((8, DIM_RUIDO))
generadas = generador(z, training=False).numpy()

fig, axes = plt.subplots(1, 8, figsize=(11, 1.6))
for ax, im in zip(axes, generadas):
    ax.imshow(im.reshape(8, 8), cmap="gray"); ax.axis("off")
fig.suptitle("Dígitos generados por la DGAN (a partir de ruido)", y=1.1); plt.show()

# %% [markdown]
# Con pocas épocas las imágenes son aún borrosas, pero ya muestran trazos parecidos a dígitos: la red
# **genera imágenes nuevas desde ruido**. Con más épocas y datos (p. ej. MNIST 28×28) la calidad mejora mucho.
#
# ## Experimenta tú
#
# 1. Sube `EPOCAS` (p. ej. 150) y observa cómo mejoran las imágenes.
# 2. Cambia `DIM_RUIDO` o el número de filtros del generador.
# 3. Genera más imágenes cambiando el tamaño del ruido en la última celda.
#
# ## Resumen
#
# - Una **DGAN** genera imágenes: el generador usa `Conv2DTranspose` para ampliar el ruido hasta una imagen.
# - El **discriminador** es una CNN que separa reales de falsas.
# - El **bucle adversario** alterna el entrenamiento de ambas redes.
# - Con esto cerramos el Módulo 3. En el siguiente veremos **redes recurrentes y NLP**.
